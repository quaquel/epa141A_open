# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

from __future__ import (unicode_literals, print_function, absolute_import,
                        division)


from ema_workbench import (Model, MultiprocessingEvaluator, SequentialEvaluator,
                           ScalarOutcome, IntegerParameter, optimize, Scenario)
from ema_workbench.em_framework.optimization import EpsilonProgress, HyperVolume
from ema_workbench.util import ema_logging
from ema_workbench import (Model, RealParameter, IntegerParameter, CategoricalParameter, ScalarOutcome, Constant)

from problem_formulation import get_model_for_problem_formulation
import matplotlib.pyplot as plt
import seaborn as sns
from ema_workbench.em_framework.samplers import sample_levers, sample_uncertainties
from ema_workbench.em_framework.evaluators import LHS, SOBOL, MORRIS, SequentialEvaluator

from __future__ import (unicode_literals, print_function, absolute_import,
                        division)


from ema_workbench import (Model, MultiprocessingEvaluator,
                           ScalarOutcome, IntegerParameter, optimize, Scenario)
from ema_workbench.em_framework.optimization import EpsilonProgress, HyperVolume
from ema_workbench.util import ema_logging

from problem_formulation import get_model_for_problem_formulation
import matplotlib.pyplot as plt
import seaborn as sns


if __name__ == '__main__':
    ema_logging.log_to_stderr(ema_logging.INFO)

    dike_model = get_model_for_problem_formulation(1)

    reference_values = {'Bmax': 175, 'Brate': 1.5, 'pfail': 0.5,
                        'discount rate': 3.5,
                        'ID flood wave shape': 4}
    scen1 = {}

    for key in dike_model.uncertainties:
        name_split = key.name.split('_')

        if len(name_split) == 1:
            scen1.update({key.name: reference_values[key.name]})

        else:
            scen1.update({key.name: reference_values[name_split[1]]})

    ref_scenario = Scenario('reference', **scen1)
    
    dike_model.uncertainties = [RealParameter('A.0_ID flood wave shape', 0, 133),
                   RealParameter('A1.Bmax', 30,350),
                   CategoricalParameter('A1.Brate',(0.9,1.5,1000)),
                   RealParameter('A1.pfail',0,1),
                   RealParameter('A2.Bmax', 30,350),
                   CategoricalParameter('A2.Brate',(0.9,1.5,1000)),
                   RealParameter('A2.pfail',0,1),
                   RealParameter('A3.Bmax', 30,350),
                   CategoricalParameter('A3.Brate',(0.9,1.5,1000)),
                   RealParameter('A3.pfail',0,1),
                   RealParameter('A4.Bmax', 30,350),
                   CategoricalParameter('A4.Brate',(0.9,1.5,1000)),
                   RealParameter('A4.pfail',0,1),
                   RealParameter('A5.Bmax', 30,350),
                   CategoricalParameter('A5.Brate',(0.9,1.5,1000)),
                   RealParameter('A5.pfail',0,1),
                   CategoricalParameter('discount rate',(1.5,2.5,3.5,4.5))]


    # set levers
    dike_model.levers = [IntegerParameter('A1.DikeIncrease',0,10),
                     IntegerParameter('A2.DikeIncrease',0,10),
                     IntegerParameter('A3.DikeIncrease',0,10),
                     IntegerParameter('A4.DikeIncrease',0,10),
                     IntegerParameter('A5.DikeIncrease',0,2), #capped this variable to test if the model uses these specified levers
                     CategoricalParameter('1_RfR',(0,1)),
                     CategoricalParameter('2_RfR',(0,1)),
                     CategoricalParameter('3_RfR',(0,1)),
                     CategoricalParameter('4_RfR',(0,1)),
                     CategoricalParameter('0_RfR',(0,1)),
                     IntegerParameter('EWS_DaysToThreat',0,4)]


    #specify outcomes
    # note how we need to explicitely indicate the direction
    dike_model.outcomes = [ScalarOutcome('Expected Annual Damage', kind=ScalarOutcome.MINIMIZE),
                  ScalarOutcome('Total Investment Costs', kind=ScalarOutcome.MINIMIZE),
                  ScalarOutcome('Expected Number of Deaths', kind=ScalarOutcome.MINIMIZE)]

    convergence_metrics = [EpsilonProgress()]

    espilon = [100000,100000,0.001]

    nfe = 10

    with SequentialEvaluator(dike_model) as evaluator:
        results, convergence = evaluator.optimize(nfe=nfe,
                                                  searchover='levers',
                                                  epsilons=espilon,
                                                  convergence=convergence_metrics,
                                                  reference=ref_scenario
                                                  )
# Out:
# [MainProcess/INFO] model initialized
# [MainProcess/INFO] generation 0: 0/10 nfe
# [MainProcess/INFO] performing 1 scenarios * 100 policies * 1 model(s) = 100 experiments
# [MainProcess/INFO] performing experiments sequentially
# [MainProcess/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/em_framework/experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/util/ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/em_framework/model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/util/ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/em_framework/model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/jhkwakkel/Documents/workspace/epa1361_open/final assignment/dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/em_framework/experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/util/ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/em_framework/model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/util/ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/jhkwakkel/Documents/workspace/EMAworkbench/ema_workbench/em_framework/model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/jhkwakkel/Documents/workspace/epa1361_open/final assignment/dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/experiment_runner.py in run_experiment(self, experiment)
#      88         try:
# ---> 89             model.run_model(scenario, policy)
#      90         except CaseError as e:
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/util/ema_logging.py in wrapper(*args, **kwargs)
#      50         debug('calling {} on {}'.format(func.__name__, classname))
# ---> 51         res = func(*args, **kwargs)
#      52         debug('completed calling {} on {}'.format(func.__name__, classname))
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/model.py in run_model(self, scenario, policy)
#     389
# --> 390         outputs = self.run_experiment(experiment)
#     391
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/util/ema_logging.py in wrapper(*args, **kwargs)
#      50         debug('calling {} on {}'.format(func.__name__, classname))
# ---> 51         res = func(*args, **kwargs)
#      52         debug('completed calling {} on {}'.format(func.__name__, classname))
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/model.py in run_experiment(self, experiment)
#     442         """
# --> 443         model_output = self.function(**experiment)
#     444
#
# ~/Documents/workspace/epa1361_open/final assignment/dike_model_function.py in __call__(self, timestep, **kwargs)
#     101                 #                print(item)
# --> 102                 string1, string2 = item.split('_')
#     103
#
# ValueError: not enough values to unpack (expected 2, got 1)
#
# During handling of the above exception, another exception occurred:
#
# EMAError                                  Traceback (most recent call last)
# <ipython-input-2-83ae584927a8> in <module>()
#     107                                                   epsilons=espilon,
#     108                                                   convergence=convergence_metrics,
# --> 109                                                   reference=ref_scenario
#     110                                                   )
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/evaluators.py in optimize(self, algorithm, nfe, searchover, reference, constraints, **kwargs)
#     179         return optimize(self._msis, algorithm=algorithm, nfe=int(nfe),
#     180                         searchover=searchover, evaluator=self,
# --> 181                         reference=reference, constraints=constraints, **kwargs)
#     182
#     183     def robust_optimize(self, robustness_functions, scenarios,
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/evaluators.py in optimize(models, algorithm, nfe, searchover, evaluator, reference, convergence, constraints, **kwargs)
#     510
#     511     return _optimize(problem, evaluator, algorithm, convergence, nfe,
# --> 512                      **kwargs)
#     513
#     514
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/optimization.py in _optimize(problem, evaluator, algorithm, convergence, nfe, **kwargs)
#     727     evaluator.callback = callback
#     728
# --> 729     optimizer.run(nfe)
#     730
#     731     results = to_dataframe(optimizer, problem.parameter_names,
#
# ~/Documents/workspace/Platypus/platypus/core.py in run(self, condition, callback)
#     302
#     303         while not condition(self):
# --> 304             self.step()
#     305
#     306             if self.log_frequency is not None and self.nfe >= last_log + self.log_frequency:
#
# ~/Documents/workspace/Platypus/platypus/algorithms.py in step(self)
#    1500
#    1501     def step(self):
# -> 1502         self.algorithm.step()
#    1503         self.iteration += 1
#    1504         self.nfe = self.algorithm.nfe
#
# ~/Documents/workspace/Platypus/platypus/algorithms.py in step(self)
#     171     def step(self):
#     172         if self.nfe == 0:
# --> 173             self.initialize()
#     174         else:
#     175             self.iterate()
#
# ~/Documents/workspace/Platypus/platypus/algorithms.py in initialize(self)
#     181
#     182     def initialize(self):
# --> 183         super(NSGAII, self).initialize()
#     184
#     185         if self.archive is not None:
#
# ~/Documents/workspace/Platypus/platypus/algorithms.py in initialize(self)
#      70     def initialize(self):
#      71         self.population = [self.generator.generate(self.problem) for _ in range(self.population_size)]
# ---> 72         self.evaluate_all(self.population)
#      73
#      74     @abstractmethod
#
# ~/Documents/workspace/Platypus/platypus/core.py in evaluate_all(self, solutions)
#     275
#     276         jobs = [_EvaluateJob(s) for s in unevaluated]
# --> 277         results = self.evaluator.evaluate_all(jobs)
#     278
#     279         # if needed, update the original solution with the results
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/evaluators.py in evaluate_all(self, jobs, **kwargs)
#     136                         reporting_frequency=self.reporting_frequency,
#     137                         scenarios=scenarios, policies=policies,
# --> 138                         return_callback=True)
#     139
#     140         experiments, outcomes = callback.get_results()
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/evaluators.py in perform_experiments(models, scenarios, policies, evaluator, reporting_interval, reporting_frequency, uncertainty_union, lever_union, outcome_union, uncertainty_sampling, levers_sampling, callback, return_callback)
#     446         evaluator = SequentialEvaluator(models)
#     447
# --> 448     evaluator.evaluate_experiments(scenarios, policies, callback)
#     449
#     450     if callback.i != nr_of_exp:
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/evaluators.py in evaluate_experiments(self, scenarios, policies, callback)
#     215
#     216         for experiment in ex_gen:
# --> 217             outcomes = runner.run_experiment(experiment)
#     218             callback(experiment, outcomes)
#     219         runner.cleanup()
#
# ~/Documents/workspace/EMAworkbench/ema_workbench/em_framework/experiment_runner.py in run_experiment(self, experiment)
#     104             errortype = type(e).__name__
#     105             raise EMAError(("exception in run_model"
# --> 106                             "\nCaused by: {}: {}".format(errortype, str(e))))
#     107
#     108         outcomes = model.outcomes_output
#
# EMAError: exception in run_model
# Caused by: ValueError: not enough values to unpack (expected 2, got 1)

# %%
import problem_formulation

# %%
model = problem_formulation.get_model_for_problem_formulation(3)
# Out:
# [MainProcess/INFO] model initialized

# %%
for l in model.levers:
    print(repr(l))
# Out:
# IntegerParameter('A.1_DikeIncrease', 0, 10)
# IntegerParameter('A.2_DikeIncrease', 0, 10)
# IntegerParameter('A.3_DikeIncrease', 0, 10)
# IntegerParameter('A.4_DikeIncrease', 0, 10)
# IntegerParameter('A.5_DikeIncrease', 0, 10)
# IntegerParameter('0_RfR', 0, 1)
# IntegerParameter('1_RfR', 0, 1)
# IntegerParameter('2_RfR', 0, 1)
# IntegerParameter('3_RfR', 0, 1)
# IntegerParameter('4_RfR', 0, 1)
# IntegerParameter('EWS_DaysToThreat', 0, 4)
