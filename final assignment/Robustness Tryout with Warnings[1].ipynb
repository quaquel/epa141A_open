# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

from __future__ import (unicode_literals, print_function, absolute_import,
                        division)


from ema_workbench import (Model, MultiprocessingEvaluator,
                           ScalarOutcome, IntegerParameter, optimize, Scenario)
from ema_workbench.em_framework.optimization import EpsilonProgress, HyperVolume
from ema_workbench.util import ema_logging
from ema_workbench import (Model, RealParameter, IntegerParameter, CategoricalParameter, ScalarOutcome, Constant)

from problem_formulation import get_model_for_problem_formulation
import matplotlib.pyplot as plt
import seaborn as sns
from ema_workbench.em_framework.samplers import sample_levers, sample_uncertainties
from ema_workbench.em_framework.evaluators import LHS, SOBOL, MORRIS, SequentialEvaluator

from __future__ import (unicode_literals, print_function, absolute_import,
                        division)


from ema_workbench import (Model, MultiprocessingEvaluator,
                           ScalarOutcome, IntegerParameter, optimize, Scenario)
from ema_workbench.em_framework.optimization import EpsilonProgress, HyperVolume
from ema_workbench.util import ema_logging

from problem_formulation import get_model_for_problem_formulation
import matplotlib.pyplot as plt
import seaborn as sns


if __name__ == '__main__':
    ema_logging.log_to_stderr(ema_logging.INFO)

    dike_model = get_model_for_problem_formulation(1)

    reference_values = {'Bmax': 175, 'Brate': 1.5, 'pfail': 0.5,
                        'discount rate': 3.5,
                        'ID flood wave shape': 4}
    scen1 = {}

    for key in dike_model.uncertainties:
        name_split = key.name.split('_')

        if len(name_split) == 1:
            scen1.update({key.name: reference_values[key.name]})

        else:
            scen1.update({key.name: reference_values[name_split[1]]})

    ref_scenario = Scenario('reference', **scen1)
    
    dike_model.uncertainties = [RealParameter('A.0_ID flood wave shape', 0, 133),
                   RealParameter('A1.Bmax', 30,350),
                   CategoricalParameter('A1.Brate',(0.9,1.5,1000)),
                   RealParameter('A1.pfail',0,1),
                   RealParameter('A2.Bmax', 30,350),
                   CategoricalParameter('A2.Brate',(0.9,1.5,1000)),
                   RealParameter('A2.pfail',0,1),
                   RealParameter('A3.Bmax', 30,350),
                   CategoricalParameter('A3.Brate',(0.9,1.5,1000)),
                   RealParameter('A3.pfail',0,1),
                   RealParameter('A4.Bmax', 30,350),
                   CategoricalParameter('A4.Brate',(0.9,1.5,1000)),
                   RealParameter('A4.pfail',0,1),
                   RealParameter('A5.Bmax', 30,350),
                   CategoricalParameter('A5.Brate',(0.9,1.5,1000)),
                   RealParameter('A5.pfail',0,1),
                   CategoricalParameter('discount rate',(1.5,2.5,3.5,4.5))]


    # set levers
    dike_model.levers = [IntegerParameter('A1.DikeIncrease',0,10),
                     IntegerParameter('A2.DikeIncrease',0,10),
                     IntegerParameter('A3.DikeIncrease',0,10),
                     IntegerParameter('A4.DikeIncrease',0,10),
                     IntegerParameter('A5.DikeIncrease',0,2), #capped this variable to test if the model uses these specified levers
                     CategoricalParameter('1_RfR',(0,1)),
                     CategoricalParameter('2_RfR',(0,1)),
                     CategoricalParameter('3_RfR',(0,1)),
                     CategoricalParameter('4_RfR',(0,1)),
                     CategoricalParameter('0_RfR',(0,1)),
                     IntegerParameter('EWS_DaysToThreat',0,4)]


    #specify outcomes
    # note how we need to explicitely indicate the direction
    dike_model.outcomes = [ScalarOutcome('Expected Annual Damage', kind=ScalarOutcome.MINIMIZE),
                  ScalarOutcome('Total Investment Costs', kind=ScalarOutcome.MINIMIZE),
                  ScalarOutcome('Expected Number of Deaths', kind=ScalarOutcome.MINIMIZE)]

    convergence_metrics = [EpsilonProgress()]

    espilon = [100000,100000,0.001]

    nfe = 10

    with MultiprocessingEvaluator(dike_model) as evaluator:
        results, convergence = evaluator.optimize(nfe=nfe,
                                                  searchover='levers',
                                                  epsilons=espilon,
                                                  convergence=convergence_metrics,
                                                  reference=ref_scenario
                                                  )
# Out:
# C:\Users\Tim\Anaconda3\lib\importlib\_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)
# [MainProcess/INFO] model initialized
# [MainProcess/INFO] pool started
# [MainProcess/INFO] generation 0: 0/10 nfe
# [MainProcess/INFO] performing 1 scenarios * 100 policies * 1 model(s) = 100 experiments
# [SpawnPoolWorker-3/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-1/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-4/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-2/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-5/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-6/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-7/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-8/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-9/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-10/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-11/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-12/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-13/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-14/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-15/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-16/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-17/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-18/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-19/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-20/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-21/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-22/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-23/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-24/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-25/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-26/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-27/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-28/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-29/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-30/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-31/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-32/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-33/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-34/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-35/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-36/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-37/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-38/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-39/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-40/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-41/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-42/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
# ...
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-88/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-89/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-90/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-91/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-92/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-93/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-94/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-95/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-96/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-97/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-98/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-99/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
# [SpawnPoolWorker-100/ERROR] not enough values to unpack (expected 2, got 1)
# Traceback (most recent call last):
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\experiment_runner.py", line 89, in run_experiment
#     model.run_model(scenario, policy)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 390, in run_model
#     outputs = self.run_experiment(experiment)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\util\ema_logging.py", line 51, in wrapper
#     res = func(*args, **kwargs)
#   File "C:\Users\Tim\Anaconda3\lib\site-packages\ema_workbench\em_framework\model.py", line 443, in run_experiment
#     model_output = self.function(**experiment)
#   File "C:\Users\Tim\Documents\Model Based Decision Making\epa1361_open-master Final Final Final\epa1361_open-master\final assignment\dike_model_function.py", line 102, in __call__
#     string1, string2 = item.split('_')
# ValueError: not enough values to unpack (expected 2, got 1)
